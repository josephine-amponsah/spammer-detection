# %%
import json
import requests
import re
import pandas as pd 
import numpy as np
import os

# %%
path_to_json = '../data-new/fake_insta_accounts'
json_files = [pos_json for pos_json in os.listdir(path_to_json) if pos_json.endswith('.json')]
# print(json_files)

# %%
df = pd.DataFrame(json_files)

# %%
df.head()
# Out:
#           0
# 0    0.json
# 1    1.json
# 2   10.json
# 3  100.json
# 4  101.json

# %%
#extracting user names from fake users folder json files
fake_users = []
for js in json_files:
    with open(os.path.join(path_to_json, js)) as json_file:
        json_text = json.load(json_file)
        user_name = json_text["graphql"]["user"]["username"]
        fake_users.append(user_name)

# %%
#transform data to data frame
# real_accounts = pd.DataFrame(columns=["user_name", "fullname", "bio", "follower_count", "followers_count", "posts", "reels", "external_url", "privacy",
#                                                 "verification","account_type", "account_category", "profile_pic", "videos", "has_channel", "total_likes"])

# %%
L = []

with open("../data-new/real_insta_accounts.json", encoding="utf-8") as json_file:
    json_text = json.load(json_file)
    for x in json_text:
        d = {}
        for k, v in x.items():
            if k == 'latestPosts':
                list = []
                for index,y in enumerate(v):
                    list.append(v[index]['likesCount'])
                index +=1
                d["likes_"] = list
            else:
                d[k] = v
        L.append(d)

# %%
real_extract = pd.DataFrame(L)

# %%
real_extract.head()
# Out:
#             id      username                                     url
# 0   2266500396   lady__jossy   https://www.instagram.com/lady__jossy  \
# 1  21942638260     ama_afrak     https://www.instagram.com/ama_afrak
# 2  26756207406      liz.naya      https://www.instagram.com/liz.naya
# 3   5551105158  12th._street  https://www.instagram.com/12th._street
# 4    422653739  nii_mantse__  https://www.instagram.com/nii_mantse__
#
#                     fullName
# 0     Amponsah Amponsah Baah  \
# 1  Gladys Ama Konadu🇮🇹🇬🇭🇳🇱🇬🇧
# 2         Liz Wilson Amoofia
# 3            Gabriel Engmann
# 4                 Nii Tetteh
#
#                                            biography externalUrl
# 0  Data Scientist \nWild honey 🍯 \nWild flower 🌺 ...        None  \
# 1  The Jesus Kind of Girl\nEducationist @gsconsul...        None
# 2  Kindly follow my Business page @accesorize_gh\...        None
# 3  Pharm D\nMPSGH\nBeat Producer\nLink up:12thstr...        None
# 4  #KingdomCitizen\nGraphic Designer/Video Editor...        None
#
#   externalUrlShimmed  followersCount  followsCount hasChannel  ...  private
# 0               None           772.0         500.0      False  ...    False  \
# 1               None          1010.0        3020.0      False  ...    False
# 2               None           672.0         536.0      False  ...    False
# 3               None           303.0         408.0      False  ...    False
# 4               None           913.0         802.0      False  ...    False
#
#   verified                                      profilePicUrl
# 0    False  https://scontent-cdg2-1.cdninstagram.com/v/t51...  \
# 1    False  https://instagram.fhph3-1.fna.fbcdn.net/v/t51....
# 2    False  https://instagram.fala4-1.fna.fbcdn.net/v/t51....
# 3    False  https://scontent-lcy1-1.cdninstagram.com/v/t51...
# 4    False  https://instagram.flba3-2.fna.fbcdn.net/v/t51....
#
#                                      profilePicUrlHD facebookPage
# 0  https://scontent-cdg2-1.cdninstagram.com/v/t51...          NaN  \
# 1  https://instagram.fhph3-1.fna.fbcdn.net/v/t51....          NaN
# 2  https://instagram.fala4-1.fna.fbcdn.net/v/t51....          NaN
# 3  https://scontent-lcy1-1.cdninstagram.com/v/t51...          NaN
# 4  https://instagram.flba3-2.fna.fbcdn.net/v/t51....          NaN
#
#   igtvVideoCount relatedProfiles
# 0            1.0              []  \
# 1            0.0              []
# 2            7.0              []
# 3            0.0              []
# 4            0.0              []
#
#                                     latestIgtvVideos  postsCount
# 0  [{'type': 'Video', 'shortCode': 'CftQGccKSlx',...        18.0  \
# 1                                                 []        16.0
# 2  [{'type': 'Video', 'shortCode': 'CbXAaiCAOIm',...       463.0
# 3                                                 []         4.0
# 4                                                 []         7.0
#
#                                               likes_
# 0   [12, 24, 19, 9, 39, 110, 91, 95, 90, 39, 56, 81]
# 1  [180, 231, 254, 80, 101, 68, 73, 68, 65, 38, 5...
# 2   [39, 58, 45, 40, 91, 63, 40, 71, 37, 76, 69, 57]
# 3                                      [7, 24, 5, 6]
# 4                   [43, 156, 179, 31, 143, 175, 81]
#
# [5 rows x 24 columns]

# %%
real_extract["med_likes"] = real_extract["likes_"].apply(np.median)
# Out:
# c:\Users\HP\Downloads\mybooks\classification-two\spammer-detection\.venv\lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,

# %%
real_extract.head(2)
# Out:
#             id     username                                    url
# 0   2266500396  lady__jossy  https://www.instagram.com/lady__jossy  \
# 1  21942638260    ama_afrak    https://www.instagram.com/ama_afrak
#
#                     fullName
# 0     Amponsah Amponsah Baah  \
# 1  Gladys Ama Konadu🇮🇹🇬🇭🇳🇱🇬🇧
#
#                                            biography externalUrl
# 0  Data Scientist \nWild honey 🍯 \nWild flower 🌺 ...        None  \
# 1  The Jesus Kind of Girl\nEducationist @gsconsul...        None
#
#   externalUrlShimmed  followersCount  followsCount hasChannel  ...  verified
# 0               None           772.0         500.0      False  ...     False  \
# 1               None          1010.0        3020.0      False  ...     False
#
#                                        profilePicUrl
# 0  https://scontent-cdg2-1.cdninstagram.com/v/t51...  \
# 1  https://instagram.fhph3-1.fna.fbcdn.net/v/t51....
#
#                                      profilePicUrlHD facebookPage
# 0  https://scontent-cdg2-1.cdninstagram.com/v/t51...          NaN  \
# 1  https://instagram.fhph3-1.fna.fbcdn.net/v/t51....          NaN
#
#   igtvVideoCount relatedProfiles
# 0            1.0              []  \
# 1            0.0              []
#
#                                     latestIgtvVideos postsCount
# 0  [{'type': 'Video', 'shortCode': 'CftQGccKSlx',...       18.0  \
# 1                                                 []       16.0
#
#                                               likes_  med_likes
# 0   [12, 24, 19, 9, 39, 110, 91, 95, 90, 39, 56, 81]       47.5
# 1  [180, 231, 254, 80, 101, 68, 73, 68, 65, 38, 5...       70.5
#
# [2 rows x 25 columns]

# %%
real_extract.columns
# Out:
# Index(['id', 'username', 'url', 'fullName', 'biography', 'externalUrl',
#        'externalUrlShimmed', 'followersCount', 'followsCount', 'hasChannel',
#        'highlightReelCount', 'isBusinessAccount', 'joinedRecently',
#        'businessCategoryName', 'private', 'verified', 'profilePicUrl',
#        'profilePicUrlHD', 'facebookPage', 'igtvVideoCount', 'relatedProfiles',
#        'latestIgtvVideos', 'postsCount', 'likes_', 'med_likes'],
#       dtype='object')

# %%
real_data = real_extract.drop(["id", "url", "externalUrlShimmed","profilePicUrlHD","igtvVideoCount", "latestIgtvVideos", "facebookPage", "relatedProfiles", "likes_"], axis = 1)

# %%
real_data["status"] = 1

# %%
fakes = []

with open("../data-new/fakes_data.json", encoding="utf-8") as json_file:
    json_text = json.load(json_file)
    for x in json_text:
        dict = {}
        for k, v in x.items():
            if k == 'latestPosts':
                list = []
                for index,y in enumerate(v):
                    list.append(v[index]['likesCount'])
                index +=1
                dict["likes_"] = list
            else:
                dict[k] = v
        fakes.append(dict)

# %%
fake_extract = pd.DataFrame(fakes)

# %%
fake_extract.head(5)
# Out:
#             id            username                                       url
# 0  44950753876            5x_77886        https://www.instagram.com/5x_77886  \
# 1         None  Restricted profile      https://www.instagram.com/mhr._.daad
# 2  44852214403          alipoco200      https://www.instagram.com/alipoco200
# 3  44600232873      maria.saberii7  https://www.instagram.com/maria.saberii7
# 4  45369596290       athena.____.a   https://www.instagram.com/athena.____.a
#
#    fullName                                          biography externalUrl
# 0  مريومه♥️  ‏‮m_argatsniyab ‬‏‪♫: 𝑺𝑶𝑺🔗. \n♫: 16: 𝒀.𝑶🐆. \n♫...        None  \
# 1       NaN                                                NaN         NaN
# 2                                                                     None
# 3                                                                     None
# 4                                                                     None
#
#   externalUrlShimmed  followersCount  followsCount hasChannel  ...  private
# 0               None            87.0        4122.0      False  ...    False  \
# 1                NaN             NaN           NaN        NaN  ...      NaN
# 2               None            85.0        6812.0      False  ...    False
# 3               None            71.0        5925.0      False  ...     True
# 4               None           138.0        5908.0      False  ...    False
#
#   verified                                      profilePicUrl
# 0    False  https://instagram.flhr4-3.fna.fbcdn.net/v/t51....  \
# 1      NaN                                                NaN
# 2    False  https://scontent-iad3-1.cdninstagram.com/v/t51...
# 3    False  https://instagram.flpb2-2.fna.fbcdn.net/v/t51....
# 4    False  https://scontent-man2-1.cdninstagram.com/v/t51...
#
#                                      profilePicUrlHD facebookPage
# 0  https://instagram.flhr4-3.fna.fbcdn.net/v/t51....          NaN  \
# 1                                                NaN          NaN
# 2  https://scontent-iad3-1.cdninstagram.com/v/t51...          NaN
# 3  https://instagram.flpb2-2.fna.fbcdn.net/v/t51....          NaN
# 4  https://scontent-man2-1.cdninstagram.com/v/t51...          NaN
#
#   igtvVideoCount relatedProfiles latestIgtvVideos  postsCount
# 0            0.0              []               []         4.0  \
# 1            NaN             NaN              NaN         NaN
# 2            0.0              []               []         5.0
# 3            0.0              []               []        23.0
# 4            0.0              []               []         4.0
#
#              likes_
# 0      [8, 7, 6, 9]
# 1               NaN
# 2   [2, 1, 0, 0, 0]
# 3                []
# 4  [55, 49, 60, 54]
#
# [5 rows x 24 columns]

# %%
fake_extract['likes_'] = fake_extract['likes_'].dropna()

# %%
fake_extract["med_likes"] = fake_extract["likes_"].apply(np.median)
# fake_extract["max_likes"] = fake_extract["likes_"].apply(max)
# fake_extract["min_likes"] = fake_extract["likes_"].apply(min)
# Out:
# c:\Users\HP\Downloads\mybooks\classification-two\spammer-detection\.venv\lib\site-packages\numpy\core\fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,

# %%
fake_data = fake_extract.drop(["id", "url", "externalUrlShimmed","profilePicUrlHD","igtvVideoCount", "latestIgtvVideos" , "facebookPage", "relatedProfiles", "likes_"], axis = 1)

# %%
fake_data["status"] = 0

# %%
full_data = pd.concat([real_data, fake_data])

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 656 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   username              656 non-null    object
#  1   fullName              644 non-null    object
#  2   biography             644 non-null    object
#  3   externalUrl           131 non-null    object
#  4   followersCount        644 non-null    float64
#  5   followsCount          644 non-null    float64
#  6   hasChannel            644 non-null    object
#  7   highlightReelCount    644 non-null    float64
#  8   isBusinessAccount     644 non-null    object
#  9   joinedRecently        644 non-null    object
#  10  businessCategoryName  65 non-null     object
#  11  private               644 non-null    object
#  12  verified              644 non-null    object
#  13  profilePicUrl         644 non-null    object
#  14  postsCount            644 non-null    float64
#  15  med_likes             526 non-null    float64
#  16  status                656 non-null    int64
# dtypes: float64(5), int64(1), object(11)
# memory usage: 92.2+ KB

# %%
full_data["businessCategoryName"].unique()
# Out:
# array([None, 'Personal Goods & General Merchandise Stores',
#        'Creators & Celebrities', 'Lifestyle Services',
#        'Food & Personal Goods', 'General Interest', 'Publishers',
#        'Business & Utility Services', nan, 'Professional Services'],
#       dtype=object)

# %%
full_data["externalUrl"] = full_data["externalUrl"].astype(bool)

# %%
full_data["externalUrl"].value_counts()
# Out:
# externalUrl
# False    513
# True     143
# Name: count, dtype: int64

# %%
full_data["profilePicUrl"] = full_data["profilePicUrl"].astype(bool)
full_data["profilePicUrl"].value_counts()
# Out:
# profilePicUrl
# True    656
# Name: count, dtype: int64

# %%
full_data.head()
# Out:
#        username                   fullName
# 0   lady__jossy     Amponsah Amponsah Baah  \
# 1     ama_afrak  Gladys Ama Konadu🇮🇹🇬🇭🇳🇱🇬🇧
# 2      liz.naya         Liz Wilson Amoofia
# 3  12th._street            Gabriel Engmann
# 4  nii_mantse__                 Nii Tetteh
#
#                                            biography  externalUrl
# 0  Data Scientist \nWild honey 🍯 \nWild flower 🌺 ...        False  \
# 1  The Jesus Kind of Girl\nEducationist @gsconsul...        False
# 2  Kindly follow my Business page @accesorize_gh\...        False
# 3  Pharm D\nMPSGH\nBeat Producer\nLink up:12thstr...        False
# 4  #KingdomCitizen\nGraphic Designer/Video Editor...        False
#
#    followersCount  followsCount hasChannel  highlightReelCount
# 0           772.0         500.0      False                 4.0  \
# 1          1010.0        3020.0      False                 8.0
# 2           672.0         536.0      False                 2.0
# 3           303.0         408.0      False                 0.0
# 4           913.0         802.0      False                 2.0
#
#   isBusinessAccount joinedRecently businessCategoryName private verified
# 0             False          False                 None   False    False  \
# 1             False          False                 None   False    False
# 2             False          False                 None   False    False
# 3             False          False                 None   False    False
# 4             False          False                 None   False    False
#
#    profilePicUrl  postsCount  med_likes  status
# 0           True        18.0       47.5       1
# 1           True        16.0       70.5       1
# 2           True       463.0       57.5       1
# 3           True         4.0        6.5       1
# 4           True         7.0      143.0       1

# %%
full_data.tail(2)
# Out:
#         username   fullName             biography  externalUrl
# 342   ninijojo47             Hi guys💣😍😍\nIm nini🙈        False  \
# 343  sara1112500  sara.1112                              False
#
#      followersCount  followsCount hasChannel  highlightReelCount
# 342            63.0        5039.0      False                 0.0  \
# 343            71.0        4982.0      False                 0.0
#
#     isBusinessAccount joinedRecently businessCategoryName private verified
# 342             False          False                 None   False    False  \
# 343             False          False                 None   False    False
#
#      profilePicUrl  postsCount  med_likes  status
# 342           True         4.0        4.0       0
# 343           True        26.0        2.5       0

# %%
full_data = full_data.sample(frac=1).reset_index(drop=True)

# %%
full_data.head(5)
# Out:
#                username                   fullName
# 0         maahgalleryyy              maahgalleryyy  \
# 1    Restricted profile                        NaN
# 2    nilirose_waternili  گلاب و عرقیجات ممتاز نیلی
# 3  pleromadanceministry             Pleroma Abankz
# 4         emmanuelesiet             Emmanuel Esiet
#
#                                            biography  externalUrl
# 0  🌙گــالری مـــاه🌙\n.\n⭐️اکسسوری های مو و شنیون⭐...        False  \
# 1                                                NaN         True
# 2  🌺گلاب و عرقیجات ممتاز نیلی 🌺\nکاشان_ نیاسر\nار...        False
# 3  MimeIsTheNewSpiritual🇬🇭\nChoreographer\nMime M...         True
# 4  Adam in @n3sbestfriendsintheworld 🎬 \nCartooni...        False
#
#    followersCount  followsCount hasChannel  highlightReelCount
# 0          3898.0         753.0      False                11.0  \
# 1             NaN           NaN        NaN                 NaN
# 2           279.0         763.0      False                 2.0
# 3          1268.0         972.0      False                 5.0
# 4        207689.0         258.0      False                10.0
#
#   isBusinessAccount joinedRecently
# 0             False          False  \
# 1               NaN            NaN
# 2              True          False
# 3             False          False
# 4             False          False
#
#                           businessCategoryName private verified
# 0                                         None   False    False  \
# 1                                          NaN     NaN      NaN
# 2  Personal Goods & General Merchandise Stores   False    False
# 3                                         None   False    False
# 4                                         None   False    False
#
#    profilePicUrl  postsCount  med_likes  status
# 0           True        66.0      172.5       0
# 1           True         NaN        NaN       0
# 2           True         4.0        3.5       0
# 3           True       255.0      105.5       1
# 4           True       174.0    14238.5       1

# %%
full_data.to_csv("../data-new/full_data.csv")

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 656 entries, 0 to 655
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   username              656 non-null    object
#  1   fullName              644 non-null    object
#  2   biography             644 non-null    object
#  3   externalUrl           656 non-null    bool
#  4   followersCount        644 non-null    float64
#  5   followsCount          644 non-null    float64
#  6   hasChannel            644 non-null    object
#  7   highlightReelCount    644 non-null    float64
#  8   isBusinessAccount     644 non-null    object
#  9   joinedRecently        644 non-null    object
#  10  businessCategoryName  65 non-null     object
#  11  private               644 non-null    object
#  12  verified              644 non-null    object
#  13  profilePicUrl         656 non-null    bool
#  14  postsCount            644 non-null    float64
#  15  med_likes             526 non-null    float64
#  16  status                656 non-null    int64
# dtypes: bool(2), float64(5), int64(1), object(9)
# memory usage: 78.3+ KB
